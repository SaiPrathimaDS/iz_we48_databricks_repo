# %%
dbutils.widgets.help()

# %%
dbutils.widgets.text("user_name","default_user")
dbutils.widgets.text("user_role","default_role")

# %%
user_name1=dbutils.widgets.get("user_name")
user_role2=dbutils.widgets.get("user_role")
user_city=dbutils.widgets.get("user_city")

print(dbutils.widgets.get("user_city"))

print(user_name1)
print(user_role2)

# %%
print("hello ..... calling dbutil .....")

# %%
def print_message():
    print("hello ..... calling dbutil .....")
    print("hi .. welcome to databricks world")

# %%
def get_df():
    from pyspark.sql.functions import lit
    df=spark.range(10).withColumn("user",lit(user_name1)).withColumn("role",lit(user_role2))
    return df

# %%
display(get_df())

# %%
dbutils.notebook.exit("noebook successfully completed .....")
