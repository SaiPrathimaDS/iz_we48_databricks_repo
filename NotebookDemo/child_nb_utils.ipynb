# %%
print("hello ..running from child nb")

# %%
def get_num_list(num_range):
    numlist=list(range(num_range))
    return numlist

# %%
def print_df(df):
    df.show(2)
    df.printSchema()
    print(f"columns...:  {df.columns}")
